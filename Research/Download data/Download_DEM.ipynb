# %% [markdown]
# # Downloading Data

# %% [markdown]
# ## Import libraries

# %%
import ee
import pandas as pd
import altair as alt
import numpy as np
import folium
import matplotlib.pyplot as plt
import pprint

# %% [markdown]
# ## Connecting to Google Engine

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=t-H1-aBiLDUMeHHQmzD7I2DbTxWXn_jNOdgdVTga4to&tc=BNMb_Y7BDhBGCEmGx9_sUSjn6taKIQ30Pp7cEAvBWFY&cc=-bS-K9_l81GVblz2bQWg-XYY6XWIrm9wmMJQpOj3Hsg
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AWgavdfkYGa27w-s6iKYV2bGQcDd_upfbUmjGYXXNYXvgFHBWdvJUPgmPFc
#
# Successfully saved authorization token.

# %%
# Coordinates can be determined with Google Engine

roi = ee.Geometry.Polygon(
        [[[60.487539824493446, 42.52185955977091],
          [60.487539824493446, 42.48642453688845],
          [60.52891021633915, 42.48642453688845],
          [60.52891021633915, 42.52185955977091]]])

# %%
dataset = ee.Image('USGS/SRTMGL1_003');
elevation = dataset.select('elevation');

# %%
maximum_pixels = 10**13 # Can be changed but not recommended

task = ee.batch.Export.image.toDrive(**{
          'image': elevation,
          'description': 'elevation',
          'folder': 'DEM',
          'region': roi,
          'maxPixels': maximum_pixels
          })
task.start()
